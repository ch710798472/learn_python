# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
f = pd.read_csv('/home/ch/edx_note/edx_data.csv')

# %%
f.columns
# Out:
# Index([u'course_id', u'userid_DI', u'registered', u'viewed', u'explored',
#        u'certified', u'final_cc_cname_DI', u'LoE_DI', u'YoB', u'gender',
#        u'grade', u'start_time_DI', u'last_event_DI', u'nevents', u'ndays_act',
#        u'nplay_video', u'nchapters', u'nforum_posts', u'roles',
#        u'incomplete_flag'],
#       dtype='object')

# %%
nation = f['final_cc_cname_DI']

# %%
count_nation = nation.value_counts()
print count_nation

# %%
count_nation.plot(kind='barh',title='nation count',figsize=(8,6),legend=True,grid=True)
plt.savefig('/home/ch/pycharm_code/edx_analytics_ustc/images/nation_count.png',dpi=600,bbox_inches="tight")

# %%
colors = ['g', 'g',' g', 'm', 'm', 'm', 'y', 'y', 'y', 'c', 'c', 'c']
count_nation.plot(kind='barh',title='nation count',figsize=(8,6),legend=True,grid=True,kwds="color=colors")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-c843bd920377> in <module>()
#       1 colors = ['g', 'g',' g', 'm', 'm', 'm', 'y', 'y', 'y', 'c', 'c', 'c']
# ----> 2 count_nation.plot(kind='barh',title='nation count',figsize=(8,6),legend=True,grid=True,kwds="color=colors")
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3495                            colormap=colormap, table=table, yerr=yerr,
#    3496                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3497                            **kwds)
#    3498     __call__.__doc__ = plot_series.__doc__
#    3499
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2585                  yerr=yerr, xerr=xerr,
#    2586                  label=label, secondary_y=secondary_y,
# -> 2587                  **kwds)
#    2588
#    2589
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2382         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2383
# -> 2384     plot_obj.generate()
#    2385     plot_obj.draw()
#    2386     return plot_obj.result
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in generate(self)
#     985         self._compute_plot_data()
#     986         self._setup_subplots()
# --> 987         self._make_plot()
#     988         self._add_table()
#     989         self._make_legend()
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1920                 w = self.bar_width / K
#    1921                 rect = self._plot(ax, self.ax_pos + (i + 0.5) * w, y, w,
# -> 1922                                   start=start, label=label, log=self.log, **kwds)
#    1923             self._add_legend_handle(rect, label, index=i)
#    1924
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1954     @classmethod
#    1955     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1956         return ax.barh(x, y, w, left=start, log=log, **kwds)
#    1957
#    1958     def _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge):
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in barh(self, bottom, width, height, left, **kwargs)
#    5171
#    5172         patches = self.bar(left=left, height=height, width=width,
# -> 5173                            bottom=bottom, orientation='horizontal', **kwargs)
#    5174         return patches
#    5175
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    5048                 label='_nolegend_'
#    5049                 )
# -> 5050             r.update(kwargs)
#    5051             r.get_path()._interpolation_steps = 100
#    5052             #print r.get_label(), label, 'label' in kwargs
#
# /usr/lib/pymodules/python2.7/matplotlib/artist.pyc in update(self, props)
#     737             func = getattr(self, 'set_' + k, None)
#     738             if func is None or not callable(func):
# --> 739                 raise AttributeError('Unknown property %s' % k)
#     740             func(v)
#     741             changed = True
#
# AttributeError: Unknown property kwds
